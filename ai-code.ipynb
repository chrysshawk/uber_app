# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %%
# get yahoo finance data
stock_df = yf.download('AAPL', start='2020-01-01', end='2020-12-31')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
plt.plot(stock_data['Adj Close']);

# %%
stock_df.head(4)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  73.449379  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.735313  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  73.314880  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.970078  108872000

# %%
stock_df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'Return'], dtype='object')

# %%
stock_df['Return'] = np.log(stock_df['Adj Close']/stock_df['Adj Close'].shift(1))
stock_df.dropna(inplace=True)
stock_df.index = pd.to_datetime(stock_df.index)

# %%
stock_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-06   73.447502   74.989998   73.187500   74.949997   73.314880
# 2020-01-07   74.959999   75.224998   74.370003   74.597504   72.970078
# 2020-01-08   74.290001   76.110001   74.290001   75.797501   74.143890
# 2020-01-09   76.809998   77.607498   76.550003   77.407501   75.718773
# 2020-01-10   77.650002   78.167503   77.062500   77.582497   75.889954
# ...                ...         ...         ...         ...         ...
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  129.209274
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.205765
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.862671
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  133.067001
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.932388
#
#                Volume    Return
# Date
# 2020-01-06  118387200  0.007937
# 2020-01-07  108872000 -0.004714
# 2020-01-08  132079200  0.015958
# 2020-01-09  170108400  0.021018
# 2020-01-10  140644800  0.002258
# ...               ...       ...
# 2020-12-23   88223700 -0.007000
# 2020-12-24   54930100  0.007683
# 2020-12-28  124486200  0.035141
# 2020-12-29  121047300 -0.013404
# 2020-12-30   96452100 -0.008563
#
# [250 rows x 7 columns]

# %%
stock_df['Return'].plot()
# Out:
# <Axes: xlabel='Date'>
